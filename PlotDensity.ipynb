# %%
import pandas as pd

# %%
books_df = pd.read_csv("book_data.csv")

# %%
books_df["range"] = (books_df.End - books_df.Begin).clip(lower=20)

# %%
books_df["density"] = books_df.Words / books_df.range

# %%
books_df
# Out:
#                   Book  Begin   End  Pages    Words  range      density
# 0                  Job  -2000 -1900   40.0  12674.0    100   126.740000
# 1              Genesis  -4000 -1405   58.0  32046.0   2595    12.349133
# 2               Exodus  -1445 -1405   49.0  25957.0     40   648.925000
# 3            Leviticus  -1445 -1405   36.0  18852.0     40   471.300000
# 4              Numbers  -1445 -1405   51.0  25048.0     40   626.200000
# 5          Deuteronomy  -1445 -1405   48.0  23008.0     40   575.200000
# 6               Psalms  -1410  -450   98.0  30147.0    960    31.403125
# 7               Joshua  -1405 -1385   29.0  15671.0     20   783.550000
# 8               Judges  -1043 -1043   30.0  15385.0     20   769.250000
# 9                 Ruth  -1030 -1010    4.0   2039.0     20   101.950000
# 10     Song of Solomon   -971  -965    6.0   2020.0     20   101.000000
# 11            Proverbs   -971  -686   34.0   9921.0    285    34.810526
# ...
